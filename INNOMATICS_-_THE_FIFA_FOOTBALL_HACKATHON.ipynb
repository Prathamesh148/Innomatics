# %% [markdown]
# # --------------------- DATA ANALYSIS & DATA MINING HACKATHON ----------------------

# %% [markdown]
# ### Importing Required Libaries:

# %%
import numpy as np                               
import pandas as pd                              
import matplotlib.pyplot as plt                 
import seaborn as sns                           
import warnings                                  
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read Dataset:

# %%
df = pd.read_csv('football_data.csv')
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %% [markdown]
# # ---------------------- Task - 1 : Data Preparation & Data Visualization  -------------------

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %% [markdown]
# # HeatMap

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.isna(), yticklabels=False, cmap='YlGnBu');

# %% [markdown]
# # Correlation Matrix

# %%
corr_ = df[df_num_fe.columns].corr()
f,ax = plt.subplots(figsize=(25, 10))
sns.heatmap(corr_,annot=True, linewidths=0.5, cmap="YlGnBu", fmt= '.1f',ax=ax)
plt.show()

# %%
def cleanMoney(column):
    val = []
    for v in df[column].fillna(''):
        if v[-1]=='M':
            m = 1000000
            m *= float(value[1:-1])
        elif v[-1]=='K':
            m = 1000
            m *= float(value[1:-1])
        else: 
            m = 0
        val.append(m/1000000)
    return val

def cleanWeight():
    wei = []
    for w in df['Weight'].fillna(''):
        if w != '':
            wei.append(int(w[:-3]))
        else:
            wei.append(np.nan)
    return wei

def cleanHeight():
    heights = []
    for h in df['Height'].fillna(''):
        if h != '':
            h =int(h[0])*12 + int(h[2])
            heights.append(h)
        else:
            heights.append(np.nan)
    return heights

def cleanReleaseCclause():
    rc = []
    for cl in df['Release Clause'].fillna(''):
        if cl == '':
            m=0.0
            
        elif cl[-1]=='M':
            m = 1000000
            m *= int(cl[1:-1])
            
        elif cl[-1]=='K':
            m = 1000
            m *= int(cl[1:-1])
            
        else: 
            m = 0
        rc.append(m/1000000)
        "df"
    return rc

# %%
df['Weight'] = cleanWeight()

# %%
df['Weight'].head()
# Out:
# 0    159.0
# 1    183.0
# 2    150.0
# 3    168.0
# 4    154.0
# Name: Weight, dtype: float64

# %%
df['Weight'].tail()
# Out:
# 18202    134.0
# 18203    170.0
# 18204    148.0
# 18205    154.0
# 18206    176.0
# Name: Weight, dtype: float64

# %%
df.hist(column='Weight')
# Out:
# array([[<AxesSubplot:title={'center':'Weight'}>]], dtype=object)

# %%
sns.kdeplot(df['Weight'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.distplot(df['Weight'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
df['Height']
# Out:
# 0         5'7
# 1         6'2
# 2         5'9
# 3         6'4
# 4        5'11
#          ...
# 18202     5'9
# 18203     6'3
# 18204     5'8
# 18205    5'10
# 18206    5'10
# Name: Height, Length: 18207, dtype: object

# %%
df['Height'] = cleanHeight()

# %%
df.Height.head()
# Out:
# 0    67.0
# 1    74.0
# 2    69.0
# 3    76.0
# 4    61.0
# Name: Height, dtype: float64

# %%
df.Height.tail()
# Out:
# 18202    69.0
# 18203    75.0
# 18204    68.0
# 18205    61.0
# 18206    61.0
# Name: Height, dtype: float64

# %%
df.hist(column='Height')
# Out:
# array([[<AxesSubplot:title={'center':'Height'}>]], dtype=object)

# %%
sns.kdeplot(df['Height'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.distplot(df['Height'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
df['Release Clause'].head()
# Out:
# 0    €226.5M
# 1    €127.1M
# 2    €228.1M
# 3    €138.6M
# 4    €196.4M
# Name: Release Clause, dtype: object

# %%
df['Release Clause'].tail()
# Out:
# 18202    €143K
# 18203    €113K
# 18204    €165K
# 18205    €143K
# 18206    €165K
# Name: Release Clause, dtype: object

# %%
df_num_fe = df[['Age', 'Overall', 'Potential', 'Value', 'Wage', 'Special', 'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy', 'Volleys', 'Dribbling', 'Curve', 
                'FKAccuracy', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 
                'Balance', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 
                'Positioning', 'Vision', 'Penalties', 'Composure', 'SlidingTackle', 'GKDiving', 
                'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']]

df_cat_fe = df[['Name','Nationality', 'Club', 'Preferred Foot', 'Work Rate','Body Type', 'Position', 
                 'International Reputation', 'Weak Foot', 'Skill Moves']]

# %%
df_num_fe.head()
# Out:
#    Age  Overall  Potential    Value   Wage  Special  Height  Weight  Crossing  \
# 0   31       94         94  €110.5M  €565K     2202    67.0   159.0      84.0
# 1   33       94         94     €77M  €405K     2228    74.0   183.0      84.0
# 2   26       92         93  €118.5M  €290K     2143    69.0   150.0      79.0
# 3   27       91         93     €72M  €260K     1471    76.0   168.0      17.0
# 4   27       91         92    €102M  €355K     2281    61.0   154.0      93.0
#
#    Finishing  ...  Positioning  Vision  Penalties  Composure  SlidingTackle  \
# 0       95.0  ...         94.0    94.0       75.0       96.0           26.0
# 1       94.0  ...         95.0    82.0       85.0       95.0           23.0
# 2       87.0  ...         89.0    87.0       81.0       94.0           33.0
# 3       13.0  ...         12.0    68.0       40.0       68.0           13.0
# 4       82.0  ...         87.0    94.0       79.0       88.0           51.0
#
# ...

# %%
df_cat_fe.head()
# Out:
#                 Name Nationality                 Club Preferred Foot  \
# 0           L. Messi   Argentina         FC Barcelona           Left
# 1  Cristiano Ronaldo    Portugal             Juventus          Right
# 2          Neymar Jr      Brazil  Paris Saint-Germain          Right
# 3             De Gea       Spain    Manchester United          Right
# 4       K. De Bruyne     Belgium      Manchester City          Right
#
#         Work Rate   Body Type Position  International Reputation  Weak Foot  \
# 0  Medium/ Medium       Messi       RF                       5.0        4.0
# 1       High/ Low  C. Ronaldo       ST                       5.0        4.0
# 2    High/ Medium      Neymar       LW                       5.0        5.0
# 3  Medium/ Medium        Lean       GK                       4.0        3.0
# 4      High/ High      Normal      RCM                       4.0        5.0
#
#    Skill Moves
# 0          4.0
# 1          5.0
# 2          5.0
# 3          1.0
# ...

# %%
df_num_fe.describe()
# Out:
#                 Age       Overall     Potential       Special        Height  \
# count  18207.000000  18207.000000  18207.000000  18207.000000  18159.000000
# mean      25.122206     66.238699     71.307299   1597.809908     68.943664
# std        4.669943      6.908930      6.136496    272.586016      5.322445
# min       16.000000     46.000000     48.000000    731.000000     61.000000
# 25%       21.000000     62.000000     67.000000   1457.000000     61.000000
# 50%       25.000000     66.000000     71.000000   1635.000000     69.000000
# 75%       28.000000     71.000000     75.000000   1787.000000     73.000000
# max       45.000000     94.000000     95.000000   2346.000000     81.000000
#
#              Weight      Crossing     Finishing  HeadingAccuracy  \
# count  18159.000000  18159.000000  18159.000000     18159.000000
# mean     165.979129     49.734181     45.550911        52.298144
# std       15.593344     18.364524     19.525820        17.379909
# ...

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x= 'Balance', y = 'Weight', data = df);
plt.ylabel('Weight', fontsize=15)
plt.xlabel('Balance', fontsize=15)
plt.title('Scatter plot b/w balance and weight', fontsize=20);

# %%
fig = plt.figure(figsize=(10, 5))
sns.distplot(x = df['Age'])
plt.title('Distribution plot of Age', fontsize=20);

# %% [markdown]
# # histogram - count of player based on age

# %%
df['Age']
# Out:
# 0        31
# 1        33
# 2        26
# 3        27
# 4        27
#          ..
# 18202    19
# 18203    19
# 18204    16
# 18205    17
# 18206    16
# Name: Age, Length: 18207, dtype: int64

# %%
df.hist(column='Age')
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
n, bins, patches = plt.hist(df.Age)

# %%
df["Wage"]
# Out:
# 0        €565K
# 1        €405K
# 2        €290K
# 3        €260K
# 4        €355K
#          ...
# 18202      €1K
# 18203      €1K
# 18204      €1K
# 18205      €1K
# 18206      €1K
# Name: Wage, Length: 18207, dtype: object

# %% [markdown]
# # -------------------------------------------- Task 2 : K-means ----------------------------------------

# %%
X = df.iloc[ : , [3,8] ]
X
# Out:
#        Age  Potential
# 0       31         94
# 1       33         94
# 2       26         93
# 3       27         93
# 4       27         92
# ...    ...        ...
# 18202   19         65
# 18203   19         63
# 18204   16         67
# 18205   17         66
# 18206   16         66
#
# [18207 rows x 2 columns]

# %%
X = X.values
X
# Out:
# array([[31, 94],
#        [33, 94],
#        [26, 93],
#        ...,
#        [16, 67],
#        [17, 66],
#        [16, 66]], dtype=int64)

# %%
df = pd.DataFrame(X, columns=['X[:,0]','X[:,1]'])
df
# Out:
#        X[:,0]  X[:,1]
# 0          31      94
# 1          33      94
# 2          26      93
# 3          27      93
# 4          27      92
# ...       ...     ...
# 18202      19      65
# 18203      19      63
# 18204      16      67
# 18205      17      66
# 18206      16      66
#
# [18207 rows x 2 columns]

# %%
plt.scatter(X[:,0],X[:,1])

# %% [markdown]
# # --------------------------------------------- for K=3 ------------------------------------------------------

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
kmeans.cluster_centers_
# Out:
# array([[29.98741624, 67.32521654],
#        [23.1211301 , 78.21163932],
#        [22.21758135, 68.64497329]])

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, ..., 2, 2, 2])

# %%
df['y'] = kmeans.labels_
df
# Out:
#        X[:,0]  X[:,1]  y
# 0          31      94  1
# 1          33      94  1
# 2          26      93  1
# 3          27      93  1
# 4          27      92  1
# ...       ...     ... ..
# 18202      19      65  2
# 18203      19      63  2
# 18204      16      67  2
# 18205      17      66  2
# 18206      16      66  2
#
# [18207 rows x 3 columns]

# %%
plt.scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], color='black')
plt.xlabel("Age")
plt.ylabel("Potential")
plt.show()

# %% [markdown]
# # --------------------------------------------- for K=5 ----------------------------------------------------

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
kmeans.cluster_centers_
# Out:
# array([[29.69901883, 72.58392999],
#        [21.55087242, 74.06775436],
#        [22.25563173, 66.82443683],
#        [29.72816374, 64.3407322 ],
#        [22.78623482, 81.62267206]])

# %%
kmeans.labels_
# Out:
# array([4, 4, 4, ..., 2, 2, 2])

# %%
df['y'] = kmeans.labels_
df
# Out:
#        X[:,0]  X[:,1]  y
# 0          31      94  4
# 1          33      94  4
# 2          26      93  4
# 3          27      93  4
# 4          27      92  4
# ...       ...     ... ..
# 18202      19      65  2
# 18203      19      63  2
# 18204      16      67  2
# 18205      17      66  2
# 18206      16      66  2
#
# [18207 rows x 3 columns]

# %%
plt.scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], color='black')
plt.xlabel("Age")
plt.ylabel("Potential")
plt.show()

# %% [markdown]
# # -------------------------------------------- for k=7 -------------------------------------------------------

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=7)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=7)

# %%
kmeans.cluster_centers_
# Out:
# array([[20.81356522, 67.73913043],
#        [21.29874386, 74.89186237],
#        [32.42623716, 66.61157796],
#        [30.0075    , 75.785     ],
#        [26.48298906, 70.11452005],
#        [21.92633703, 82.19929364],
#        [26.37666371, 62.68855368]])

# %%
kmeans.labels_
# Out:
# array([5, 5, 5, ..., 0, 0, 0])

# %%
df['y'] = kmeans.labels_
df
# Out:
#        X[:,0]  X[:,1]  y
# 0          31      94  5
# 1          33      94  5
# 2          26      93  5
# 3          27      93  5
# 4          27      92  5
# ...       ...     ... ..
# 18202      19      65  0
# 18203      19      63  0
# 18204      16      67  0
# 18205      17      66  0
# 18206      16      66  0
#
# [18207 rows x 3 columns]

# %%
plt.scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], color='black')
plt.xlabel("Age")
plt.ylabel("Potential")
plt.show()

# %% [markdown]
# # ---------------------------------- Task 3 - Hierarchical Clustering -------------------------------

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, cut_tree

# %%
mergings = linkage(df, method='single', metric='euclidean')
dendrogram(mergings)
plt.show();

# %%
mergings = linkage(df, method='complete', metric='euclidean')
dendrogram(mergings)
plt.show();

# %%
cluster_labels = cut_tree(mergings, n_clusters=5)
cluster_labels
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [3],
#        [3],
#        [3]])

# %%
cluster_labels.reshape(1,-1)
# Out:
# array([[0, 0, 1, ..., 3, 3, 3]])

# %%
df.head()
# Out:
#    X[:,0]  X[:,1]  y  Dendrogram_labels
# 0      31      94  5                  0
# 1      33      94  5                  0
# 2      26      93  5                  1
# 3      27      93  5                  1
# 4      27      92  5                  1

# %%
df['Dendrogram_labels'] = cluster_labels

# %%
df.head()
# Out:
#    X[:,0]  X[:,1]  y  Dendrogram_labels
# 0      31      94  5                  0
# 1      33      94  5                  0
# 2      26      93  5                  1
# 3      27      93  5                  1
# 4      27      92  5                  1

# %%
df.columns
# Out:
# Index(['X[:,0]', 'X[:,1]', 'y', 'Dendrogram_labels'], dtype='object')

# %%
df.y.value_counts()
# Out:
# 1    3662
# 4    3292
# 0    2875
# 6    2256
# 2    2140
# 3    2000
# 5    1982
# Name: y, dtype: int64

# %%
sns.scatterplot(x='X[:,0]', y='X[:,1]',hue='y', data=df);

# %%
df.Dendrogram_labels.value_counts()
# Out:
# 3    8594
# 2    6282
# 1    1775
# 0    1148
# 4     408
# Name: Dendrogram_labels, dtype: int64

# %%
sns.scatterplot(x='X[:,0]', y='X[:,1]', hue='Dendrogram_labels', data=df);

# %% [markdown]
# # ------------------------------------------- Task 4 - DBScan -------------------------------------------

# %%
array=df.iloc[ : , [3,8] ]
from sklearn.preprocessing import StandardScaler
stsclr=StandardScaler().fit(array)
norm_data=stsclr.transform(array)

# %%
from sklearn.cluster import DBSCAN
model=DBSCAN(eps=0.8,min_samples=6).fit(norm_data)
clusters=pd.DataFrame(model.labels_,columns=['clusters'])
clusters.value_counts()
final_data=pd.concat([clusters,df],axis=1)
final_data.groupby(final_data.clusters).sum()
# Out:
#           Unnamed: 0          ID     Age  Overall  Potential   Special  \
# clusters
# -1             40691      246919     173      260        260      4290
#  0         165697630  3901482932  457227  1205748    1298032  29087035
#
#           International Reputation  Weak Foot  Skill Moves  Jersey Number  \
# clusters
# -1                             8.0        9.0          4.0          100.0
#  0                         20207.0    53511.0      42875.0       354603.0
#
#           ...  Penalties  Composure   Marking  StandingTackle  SlidingTackle  \
# clusters  ...
# -1        ...       84.0      234.0      70.0            53.0           49.0
#  0        ...   881510.0  1064760.0  858517.0        866092.0       829117.0
#
#           GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes
# clusters
# -1           251.0       255.0      239.0          272.0       247.0
#  0        301483.0    297400.0   294519.0       297334.0    303206.0
#
# [2 rows x 46 columns]

# %% [markdown]
# # ----------------------------------------------- Thankyou ------------------------------------------------
